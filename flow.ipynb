# %%
import collections
import logging
import os
import pathlib
import re
import string
import sys
import time

import numpy as np
import matplotlib.pyplot as plt

# import tensorflow_datasets as tfds
#  import tensorflow_text as text
import tensorflow as tf

# %% [markdown]
# Positional Encoding

# %%
def get_angles(pos, i, d_model):
    angle_rates = 1 / np.power(10000, (2 * (i//2)) / np.float32(d_model))
    return pos * angle_rates

# %%
def positional_encoding(pos, d_model):
    angle_rads = get_angles(np.arrange(pos)[:,:np.newaxis], \
        np.arrange(d_model)[np.newaxis,:], d_model)
    # sin for even num indices
    angle_rads[:, 0::2] = np.sin(angle_rads[:,0::2])
    # cos for odd num indices
    angle_rads[:, 1::2] = np.cos(angle_rads[:,1::2])

    pos_encoding = angle_rads[np.newaxis, ...]
    return tf.cast(pos_encoding, dtype=tf.float32)

# %%
n, d = 2048, 512
pos_encoding = positional_encoding(n, d)
print(pos_encoding.shape)
pos_encoding = pos_encoding[0]

# Juggle the dimensions for the plot
pos_encoding = tf.reshape(pos_encoding, (n, d//2, 2))
pos_encoding = tf.transpose(pos_encoding, (2, 1, 0))
pos_encoding = tf.reshape(pos_encoding, (d, n))

plt.pcolormesh(pos_encoding, cmap='RdBu')
plt.ylabel('Depth')
plt.xlabel('Position')
plt.colorbar()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\KIST\Documents\GitHub\Transformer-w--Pytorch\flow.ipynb Cell 5' in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/Users/KIST/Documents/GitHub/Transformer-w--Pytorch/flow.ipynb#ch0000004?line=0'>1</a> n, d = 2048, 512
# ----> <a href='vscode-notebook-cell:/c%3A/Users/KIST/Documents/GitHub/Transformer-w--Pytorch/flow.ipynb#ch0000004?line=1'>2</a> pos_encoding = positional_encoding(n, d)
#       <a href='vscode-notebook-cell:/c%3A/Users/KIST/Documents/GitHub/Transformer-w--Pytorch/flow.ipynb#ch0000004?line=2'>3</a> print(pos_encoding.shape)
#       <a href='vscode-notebook-cell:/c%3A/Users/KIST/Documents/GitHub/Transformer-w--Pytorch/flow.ipynb#ch0000004?line=3'>4</a> pos_encoding = pos_encoding[0]
#
# c:\Users\KIST\Documents\GitHub\Transformer-w--Pytorch\flow.ipynb Cell 4' in positional_encoding(pos, d_model)
#       <a href='vscode-notebook-cell:/c%3A/Users/KIST/Documents/GitHub/Transformer-w--Pytorch/flow.ipynb#ch0000003?line=0'>1</a> def positional_encoding(pos, d_model):
# ----> <a href='vscode-notebook-cell:/c%3A/Users/KIST/Documents/GitHub/Transformer-w--Pytorch/flow.ipynb#ch0000003?line=1'>2</a>     angle_rads = get_angles(np.arrange(pos)[:,:np.newaxis], \
#       <a href='vscode-notebook-cell:/c%3A/Users/KIST/Documents/GitHub/Transformer-w--Pytorch/flow.ipynb#ch0000003?line=2'>3</a>         np.arrange(d_model)[np.newaxis,:], d_model)
#       <a href='vscode-notebook-cell:/c%3A/Users/KIST/Documents/GitHub/Transformer-w--Pytorch/flow.ipynb#ch0000003?line=3'>4</a>     # sin for even num indices
#       <a href='vscode-notebook-cell:/c%3A/Users/KIST/Documents/GitHub/Transformer-w--Pytorch/flow.ipynb#ch0000003?line=4'>5</a>     angle_rads[:, 0::2] = np.sin(angle_rads[:,0::2])
#
# File c:\Users\KIST\.conda\envs\spleeter\lib\site-packages\numpy\__init__.py:214, in __getattr__(attr)
#     212     return Tester
#     213 else:
# --> 214     raise AttributeError("module {!r} has no attribute "
#     215                          "{!r}".format(__name__, attr))
#
# AttributeError: module 'numpy' has no attribute 'arrange'

# %%
np.__version__
# Out:
# '1.19.2'
